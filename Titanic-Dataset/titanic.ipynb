# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("tested.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False)
# Out:
# <Axes: >

# %%
sns.set_style("whitegrid")
sns.countplot(x="Survived",data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.set_style("whitegrid")
sns.countplot(x="Survived",hue="Sex",data=df,palette="rainbow")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Sex",data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df[(df["Sex"]=="male")&(df["Survived"]==False)]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %%
df[df["Sex"]=="male"].count()
# Out:
# PassengerId    266
# Survived       266
# Pclass         266
# Name           266
# Sex            266
# Age            205
# SibSp          266
# Parch          266
# Ticket         266
# Fare           265
# Cabin           47
# Embarked       266
# dtype: int64

# %%
sns.countplot(x="Survived",data=df,hue="Pclass",palette="rainbow")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.distplot(df["Age"].dropna(),kde=False,color="darkred")
# Out:
# /var/folders/9s/v2wd_mfs2bd8t2400gj5kq0c0000gn/T/ipykernel_45247/2393477766.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"].dropna(),kde=False,color="darkred")
# <Axes: xlabel='Age'>

# %%
sns.countplot(x="SibSp",data=df)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
sns.countplot(x="Parch",data=df)
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
df["Fare"].hist(bins=40)
# Out:
# <Axes: >

# %%
sns.barplot(x="Fare",y="Sex",data=df)
# Out:
# <Axes: xlabel='Fare', ylabel='Sex'>

# %%
sns.countplot(x="Embarked",hue="Sex",data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.boxplot(x="Pclass",y="Age",data=df,palette="winter")
# Out:
# /var/folders/9s/v2wd_mfs2bd8t2400gj5kq0c0000gn/T/ipykernel_45247/2686422955.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Pclass",y="Age",data=df,palette="winter")
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
def cal_age(df1):
    age=df1[0]
    pclass=df1[1]
    if pd.isnull(age):
        if pclass==1:
            return 42
        elif pclass==2:
            return 25
        else:
            return 23
    else:
        return age

# %%
df["Age"]=df[["Age","Pclass"]].apply(cal_age,axis=1)
# Out:
# /var/folders/9s/v2wd_mfs2bd8t2400gj5kq0c0000gn/T/ipykernel_45247/3806183375.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   age=df1[0]
# /var/folders/9s/v2wd_mfs2bd8t2400gj5kq0c0000gn/T/ipykernel_45247/3806183375.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pclass=df1[1]

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df["Fare"].replace(np.nan,df["Fare"].mean(),inplace=True)
# Out:
# /var/folders/9s/v2wd_mfs2bd8t2400gj5kq0c0000gn/T/ipykernel_45247/1355082939.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Fare"].replace(np.nan,df["Fare"].mean(),inplace=True)

# %%
df["Fare"].isna().any()
# Out:
# False

# %%
df.drop("Cabin",axis=1,inplace=True)

# %%
sns.heatmap(df.isna(),yticklabels=False)
# Out:
# <Axes: >

# %%
#Feature Engineering
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked
# 0   330911   7.8292        Q
# 1   363272   7.0000        S
# 2   240276   9.6875        Q
# 3   315154   8.6625        S
# 4  3101298  12.2875        S

# %%
sex=pd.get_dummies(df["Sex"],dtype=int,drop_first=True)

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
embarked=pd.get_dummies(df["Embarked"],dtype=int,drop_first=True)
embarked
# Out:
#      Q  S
# 0    1  0
# 1    0  1
# 2    1  0
# 3    0  1
# 4    0  1
# ..  .. ..
# 413  0  1
# 414  0  0
# 415  0  1
# 416  0  1
# 417  0  0
#
# [418 rows x 2 columns]

# %%
df.drop(["Sex","Embarked","Name","Ticket"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0          892         0       3  34.5      0      0   7.8292
# 1          893         1       3  47.0      1      0   7.0000
# 2          894         0       2  62.0      0      0   9.6875
# 3          895         0       3  27.0      0      0   8.6625
# 4          896         1       3  22.0      1      1  12.2875

# %%
df=pd.concat([df,sex,embarked],axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0          892         0       3  34.5      0      0   7.8292     1  1  0
# 1          893         1       3  47.0      1      0   7.0000     0  0  1
# 2          894         0       2  62.0      0      0   9.6875     1  1  0
# 3          895         0       3  27.0      0      0   8.6625     1  0  1
# 4          896         1       3  22.0      1      1  12.2875     0  0  1

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0          892         0       3  34.5      0      0   7.8292     1  1  0
# 1          893         1       3  47.0      1      0   7.0000     0  0  1
# 2          894         0       2  62.0      0      0   9.6875     1  1  0
# 3          895         0       3  27.0      0      0   8.6625     1  0  1
# 4          896         1       3  22.0      1      1  12.2875     0  0  1

# %%
df["Q"].dtype
# Out:
# dtype('int64')

# %%
sns.barplot(x=df["Pclass"],y=df["Fare"],hue=df["male"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.scatterplot(x=df["Age"],y=df["Fare"],hue=df["male"],style=df["Survived"])
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.kdeplot(df[df["Survived"]==0]["Age"])
sns.kdeplot(df[df["Survived"]==1]["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(x=df["male"],y=df["Age"],hue=df["Survived"])
# Out:
# <Axes: xlabel='male', ylabel='Age'>

# %%
df[df["male"]==1][df["Survived"]==1]["male"]
# Out:
# /var/folders/9s/v2wd_mfs2bd8t2400gj5kq0c0000gn/T/ipykernel_45247/1226200369.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["male"]==1][df["Survived"]==1]["male"]
# Series([], Name: male, dtype: int64)

# %%
sns.kdeplot(df[df["SibSp"]==1]["Age"],legend=True) 
sns.kdeplot(df[df["SibSp"]==0]["Age"],legend=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df["Survived"].dtype
# Out:
# dtype('int64')

# %%
df["Parch"].value_counts()
# Out:
# Parch
# 0    324
# 1     52
# 2     33
# 3      3
# 4      2
# 9      2
# 6      1
# 5      1
# Name: count, dtype: int64

# %%
df["SibSp"].value_counts()
# Out:
# SibSp
# 0    283
# 1    110
# 2     14
# 3      4
# 4      4
# 8      2
# 5      1
# Name: count, dtype: int64

# %%
sns.barplot(x=df["Parch"],y=df["Age"],hue=df["Survived"])
# Out:
# <Axes: xlabel='Parch', ylabel='Age'>

# %%
sns.kdeplot(df[df["male"]==1]["SibSp"])
sns.kdeplot(df[df["male"]==0]["SibSp"])
# Out:
# <Axes: xlabel='SibSp', ylabel='Density'>

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  418.000000  418.000000
# mean   1100.500000    0.363636    2.265550   29.209330    0.447368
# std     120.810458    0.481622    0.841838   13.074099    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   23.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   25.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   36.375000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare        male           Q           S
# count  418.000000  418.000000  418.000000  418.000000  418.000000
# mean     0.392344   35.627188    0.636364    0.110048    0.645933
# std      0.981429   55.840500    0.481622    0.313324    0.478803
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
#Categorical-Categorical
pd.crosstab(df["Pclass"],df["Survived"])
# Out:
# Survived    0   1
# Pclass
# 1          57  50
# 2          63  30
# 3         146  72

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
sns.barplot(x=df["Pclass"],y=df["Fare"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.heatmap(pd.crosstab(df["Pclass"],df["Survived"]))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(df.groupby("Pclass")["Survived"].mean()).plot(kind="pie")
# Out:
# <Axes: ylabel='Survived'>

# %%
(df.groupby("male")["Survived"].mean()).plot(kind="bar")
# Out:
# <Axes: xlabel='male'>

# %%
pd.crosstab(df["male"],df["Survived"])
# Out:
# Survived    0    1
# male
# 0           0  152
# 1         266    0

# %%
df["male"].value_counts()
# Out:
# male
# 1    266
# 0    152
# Name: count, dtype: int64

# %%
sns.heatmap(pd.crosstab(df["male"],df["Survived"]))
# Out:
# <Axes: xlabel='Survived', ylabel='male'>

# %%
sns.clustermap(pd.crosstab(df["Parch"],df["Survived"]))

# %%
sns.pairplot(df[["Pclass","Age","Fare","SibSp","Parch","Survived"]],hue="Survived")

# %%
#lineplot is an extension of scatterplot
#lineplot must be used when there is time based data on the x-axis

# %%
data=sns.load_dataset("flights")
data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.heatmap(data.pivot_table(values="passengers",index="year",columns="month"))
# Out:
# /var/folders/9s/v2wd_mfs2bd8t2400gj5kq0c0000gn/T/ipykernel_45247/1473724703.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(data.pivot_table(values="passengers",index="year",columns="month"))
# <Axes: xlabel='month', ylabel='year'>

# %%
new=pd.DataFrame(data.groupby("year")["passengers"].sum().reset_index())
new
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.lineplot(x=new["year"],y=new["passengers"])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop("Survived",axis=1),df["Survived"],test_size=0.30,random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# /Users/nixy/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions=model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
accuracy=confusion_matrix(y_test,predictions)
accuracy
# Out:
# array([[71,  0],
#        [ 0, 55]])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy=accuracy_score(y_test,predictions)

# %%
accuracy
# Out:
# 1.0
